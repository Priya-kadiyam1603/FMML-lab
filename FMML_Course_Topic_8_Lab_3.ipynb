# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-kadiyam1603/FMML-lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 10:38:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   200MB/s    in 0.3s
#
# 2024-03-31 10:38:36 (200 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6526   1703.00839v1  Information that is stored in an encrypted for...  stat
# 36335   1206.6861v1  This paper proposes new formulas for the proba...  stat
# 16532  1703.09817v3  A significant source of errors in Automatic Sp...    cs
# 37076  1606.06888v1  Zero-sum stochastic games provide a rich model...    cs
# 18876   1301.0582v1  The Reverse Water Gas Shift system (RWGS) is a...    cs
# ...             ...                                                ...   ...
# 12246  1710.10388v1  There has been a recent surge of interest in s...  stat
# 23017  1802.00568v1  Topic models are Bayesian models that are freq...  stat
# 8203   1612.01981v1  The intermediate map responses of a Convolutio...    cs
# 2193   1705.07224v2  Approximate probabilistic inference algorithms...  stat
# 22608  1702.07254v1  Learning rates for regularized least-squares a...  stat
#
#                                                    title  year  \
# 6526      Encrypted accelerated least squares regression  2017
# 36335  Stratified Analysis of `Probabilities of Causa...  2012
# 16532  Learning Similarity Functions for Pronunciatio...  2017
# 37076  Structure in the Value Function of Two-Player ...  2016
# 18876  Monitoring a Complez Physical System using a H...  2012
# ...                                                  ...   ...
# 12246  Minimax Rates and Efficient Algorithms for Noi...  2017
# 23017  An Instability in Variational Inference for To...  2018
# 8203    Core Sampling Framework for Pixel Classification  2016
# 2193   AIDE: An algorithm for measuring the accuracy ...  2017
# 22608  Sobolev Norm Learning Rates for Regularized Le...  2017
#
#                                                 keywords
# 6526   [information, encrypted, definition, statistic...
# 36335  [probabilities, causation, quantities, probabi...
# 16532  [significant, automatic, recognition, pronunci...
# 37076  [stochastic, competitive, uncertainty, conside...
# 18876  [atmosphere, supervision, requiring, automated...
# ...                                                  ...
# 12246  [permutation, comparison, structurally, parame...
# 23017  [frequently, structure, documents, collection,...
# 8203   [intermediate, responses, convolutional, infor...
# 2193   [approximate, probabilistic, inference, algori...
# 22608  [regularized, algorithms, expressed, equivalen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6526     [information, encrypted, definition, statistic...
# 36335    [probabilities, causation, quantities, probabi...
# 16532    [significant, automatic, recognition, pronunci...
# 37076    [stochastic, competitive, uncertainty, conside...
# 18876    [atmosphere, supervision, requiring, automated...
#                                ...
# 22874    [fundamental, inferring, direction, univariate...
# 22753    [increasing, attention, calibrated, posterior,...
# 7679     [motivation, digitization, databases, consisti...
# 24162    [different, nuisances, occlusion, signature, g...
# 10775    [retrieving, experiments, experiment, experime...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8931 words.
# Out of those 4591 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e2dfce82-c203-49dd-a0d2-fcab989e95a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2dfce82-c203-49dd-a0d2-fcab989e95a3")) {                    Plotly.newPlot(                        "e2dfce82-c203-49dd-a0d2-fcab989e95a3",                        [{"x":["algorithms","conventional","characteristics","approximating","empirically","definition","demonstrates","correctness","compromising","encrypted","computation","encryption","statistical","computational","acceleration","possibility","regression","information","theoretical","accelerated","homomorphic","technique","parameter","coordinate","assumptions","identifiable","selection","prevention","assessment","estimation","assumption","viewpoint","causation","probabilities","covariate","generating","observational","quantities","stratified","providing","experimental","dynamically","pronunciations","recognition","demonstrate","spontaneous","recurrent","predicting","similarity","neighborhoods","canonical","automatic","conversational","variations","generalizes","pronunciation","switchboard","classification","graphical","significant","different","functions","efficiency","individual","competitive","understood","introduce","structure","sufficient","convexity","observations","observable","transferring","distribution","uncertainty","contribution","formulation","developing","incomplete","generalization","characterizing","statistics","concavity","centralized","capability","partially","statistic","stochastic","appropriately","particular","potential","delineate","considered","marginals","structural","distributions","occurring","automated","specifically","requiring","successful","extending","framework","granularities","manifested","techniques","variables","monitoring","integration","supervision","applications","demonstrating","unscented","nonlinear","inference","challenges","including","collected","presented","processes","atmosphere","feasibility","continuous","important","probabilistic","numerical","penalized","simulations","estimates","consistent","expectation","considers","coefficients","reconstruction","application","algorithm","conditions","estimator","performance","heterogeneous","likelihood","challenging","precision","resulting","degeneracy","dimensional","maximization","identifiability","regularity","parameters","automatically","understanding","components","recovered","spectroscopy","contained","sufficiently","simulation","underlying","redundant","convolution","usability","clustering","experiments","competing","intuitions","principal","conducted","eigenvectors","adjacency","determine","understand","population","obtaining","accordingly","operators","unbalanced","approximations","efficient","classifier","following","negativity","misclassification","classifiers","relaxation","minimizes","numerically","constraint","parametric","profitability","evaluated","forecasting","generated","reference","predictions","evaluation","regularization","objectively","effectiveness","criterion"],"y":[574,119,86,21,81,45,39,18,5,2,156,5,140,274,10,37,87,704,142,14,1,242,122,23,61,2,155,9,48,215,80,17,1,62,2,98,6,18,4,91,406,29,2,379,568,9,146,70,125,8,16,183,15,73,34,2,6,512,62,271,751,199,172,115,106,28,319,344,73,9,70,25,16,228,89,72,97,62,36,110,17,63,3,8,57,50,8,138,13,260,184,5,123,7,59,112,12,87,172,39,84,41,525,5,4,382,129,40,50,59,436,36,1,57,216,117,225,98,190,103,4,19,95,324,151,77,10,37,73,88,26,37,40,107,238,842,147,31,865,29,62,266,83,170,1,177,34,5,9,244,205,177,106,17,1,16,16,65,122,26,44,7,166,604,26,2,22,93,8,3,76,82,53,35,19,50,4,36,396,142,87,3,10,109,13,22,8,98,46,2,127,21,155,57,74,260,83,5,222,37],"type":"bar"},{"x":["algorithms","conventional","characteristics","approximating","empir ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4591,), (4591, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Limbo</span> <span style=''>A</span> <span style=''>Fast</span> <span style=''>and</span> <span style=''>Flexible</span> <span style=''>Library</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Limbo</span> <span style=''>is</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>C11</span> <span style=''>library</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>which</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>both</span> <span style=''>highly</span> <span style=''>flexible</span> <span style=''>and</span> <span style=''>very</span> <span style=''>fast</span> <span style=''>It</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>optimize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>is</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.34210526315789463);'>evaluations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style=''>runtime</span> <span style=''>cost</span> <span style=''>matters</span> <span style=''>(eg</span> <span style=''>on</span> <span style=''>embedded</span> <span style=''>systems</span> <span style=''>or</span> <span style=''>robots)</span> <span style='background-color:rgba(0, 255, 0, 0.49230769230769217);'>Benchmarks</span> <span style=''>on</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Limbo</span> <span style=''>is</span> <span style=''>about</span> <span style=''>2</span> <span style=''>times</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>BayesOpt</span> <span style=''>(another</span> <span style=''>C</span> <span style=''>library)</span> <span style=''>for</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>accuracy</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Variance</span> <span style=''>reduced</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>rank</span> <span style=''>Matrix</span> <span style=''>Recovery</span> <span style=''>from</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Measurements</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>from</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>(aka</span> <span style=''>matrix</span> <span style=''>sensing)</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonconvex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>variance</span> <span style=''>reduced</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonconvex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>matrix</span> <span style=''>sensing</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>both</span> <span style=''>noisy</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>noiseless</span> <span style=''>settings</span> <span style=''>In</span> <span style=''>the</span> <span style=''>case</span> <span style=''>with</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>at</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>rate</span> <span style=''>up</span> <span style=''>to</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>error</span> <span style=''>And</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>noiseless</span> <span style=''>setting</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>linearly</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>achieves</span> <span style=''>exact</span> <span style=''>recovery</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>Learns</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dynamical</span> <span style=''>Systems</span> <br/><br/><span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3055555555555556);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>optimizer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5079365079365079);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>linear</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3043478260869565);'>invariant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamical</span> <span style=''>system</span> <span style=''>from</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>noisy</span> <span style='background-color:rgba(255, 0, 0, 0.3859649122807018);'>observations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>system</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>is</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>running</span> <span style=''>time</span> <span style=''>and</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>bounds</span> <span style=''>under</span> <span style=''>strong</span> <span style=''>but</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.4351851851851852);'>assumptions</span> <span style=''>Linear</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>for</span> <span style=''>many</span> <span style=''>decades</span> <span style=''>yet</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.40117416829745595);'>knowledge</span> <span style=''>these</span> <span style=''>are</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>consider</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Modularity</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>for</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Trajectories</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>moving</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>road</span> <span style=''>network</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>builds</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>on</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>then</span> <span style=''>uses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modularity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>hiearchical</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>to</span> <span style=''>regroup</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>with</span> <span style=''>similar</span> <span style=''>profiles</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>study</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>superiority</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>over</span> <span style=''>classic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>gives</span> <span style=''>a</span> <span style=''>brief</span> <span style=''>insight</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>results</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08536585365853659)
# 	knowledge (0.1284074605451937)
# 	representation (0.13163558106169296)
# 	experimental (0.14562410329985653)
# 	segmentation (0.07568149210903874)
# 	information (0.25251076040172166)
# 	detection (0.12338593974175036)
# 	different (0.2693687230989957)
# 	convolutional (0.13163558106169296)
# 	recognition (0.13593974175035867)
#
# Some Statistics words are:
# 	distribution (0.17246520874751492)
# 	stochastic (0.1411530815109344)
# 	algorithm (0.3946322067594433)
# 	variables (0.13916500994035785)
# 	theoretical (0.14463220675944333)
# 	estimation (0.17992047713717693)
# 	statistical (0.16500994035785288)
# 	inference (0.19383697813121273)
# 	dimensional (0.20029821073558648)
# 	regression (0.18687872763419483)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f104fa5b-06dc-4f00-8c17-816a5ebdd626" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f104fa5b-06dc-4f00-8c17-816a5ebdd626")) {                    Plotly.newPlot(                        "f104fa5b-06dc-4f00-8c17-816a5ebdd626",                        [{"x":["algorithms","conventional","characteristics","approximating","empirically","definition","demonstrates","correctness","compromising","encrypted","computation","encryption","statistical","computational","acceleration","possibility","regression","information","theoretical","accelerated","homomorphic","technique","parameter","coordinate","assumptions","identifiable","selection","prevention","assessment","estimation","assumption","viewpoint","causation","probabilities","covariate","generating","observational","quantities","stratified","providing","experimental","dynamically","pronunciations","recognition","demonstrate","spontaneous","recurrent","predicting","similarity","neighborhoods","canonical","automatic","conversational","variations","generalizes","pronunciation","switchboard","classification","graphical","significant","different","functions","efficiency","individual","competitive","understood","introduce","structure","sufficient","convexity","observations","observable","transferring","distribution","uncertainty","contribution","formulation","developing","incomplete","generalization","characterizing","statistics","concavity","centralized","capability","partially","statistic","stochastic","appropriately","particular","potential","delineate","considered","marginals","structural","distributions","occurring","automated","specifically","requiring","successful","extending","framework","granularities","manifested","techniques","variables","monitoring","integration","supervision","applications","demonstrating","unscented","nonlinear","inference","challenges","including","collected","presented","processes","atmosphere","feasibility","continuous","important","probabilistic","numerical","penalized","simulations","estimates","consistent","expectation","considers","coefficients","reconstruction","application","algorithm","conditions","estimator","performance","heterogeneous","likelihood","challenging","precision","resulting","degeneracy","dimensional","maximization","identifiability","regularity","parameters","automatically","understanding","components","recovered","spectroscopy","contained","sufficiently","simulation","underlying","redundant","convolution","usability","clustering","experiments","competing","intuitions","principal","conducted","eigenvectors","adjacency","determine","understand","population","obtaining","accordingly","operators","unbalanced","approximations","efficient","classifier","following","negativity","misclassification","classifiers","relaxation","minimizes","numerically","constraint","parametric","profitability","evaluated","forecasting","generated","reference","predictions","evaluation","regularization","objectively","effectiveness","criterion","investigate","evaluating","extracting","addressed","processing","researchers","disciplines","expository","developments","solutions","literature","languages","inflection","effective","recommend","factorization","filtering","independent","collaborative","published","parametrisation","procedures","substantial","equations","derivation","accompany","derivations","developed","variational","appropriate","references","collecting","implemented","therefore","implementation","knowledge","secondary","distributed","sequences","approximation","structured","corroborate","procedure","approaches","literatures","sequential","factorial","computers","invertibility","interested","existence","engineering","challenge","mechanisms","effe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrisation
# 	invertibility
# 	frequentist
# 	semiparametric
# 	submodularity
# 	bernstein
# 	prioritization
# 	disaggregation
# 	unmeasured
# 	dendrogram
# 	versatility
# 	robustification
# 	collapsed
# 	methodologically
# 	penalization
# 	robustify
# 	postulated
# 	permeates
# 	advocated
# 	pessimistic
# Some words which never appear in Statistics papers:
# 	spontaneous
# 	conversational
# 	switchboard
# 	delineate
# 	atmosphere
# 	profitability
# 	inflection
# 	logically
# 	vanishingexploding
# 	volumetric
# 	princeton
# 	modularized
# 	personalization
# 	consolidates
# 	specialists
# 	hazardous
# 	speculate
# 	reconciling
# 	surrounded
# 	benefiting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079671091127468e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
